# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("tested.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    str
#  4   Sex          418 non-null    str
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    str
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     str
#  11  Embarked     418 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 39.3 KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
sns.countplot(x='Sex' ,hue='Survived' , data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
Insight:
Female passengers had a higher survival rate compared to males.
This suggests that women were given priority during evacuation.

# %%
df['FamilySize'] = df['SibSp'] + df['Parch'] + 1

# %%
sns.countplot(x='Survived' , data = df)
plt.show()

# %%
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.show()

# %%
Passengers in 1st class had a higher survival rate compared to 2nd and 3rd class.
This indicates that socio-economic status influenced survival chances.

# %%
sns.countplot(x='Embarked',hue='Survived',data=df)
plt.show()

# %%
Passengers who embarked from port 'C' had a relatively higher survival rate compared to other ports.

# %%
df['Sex'] = df['Sex'].map({'male': 0, 'female': 1})

df = pd.get_dummies(df, columns=['Embarked'], drop_first=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name  Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    0  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)    1  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    0  62.0      0      0
# 3                              Wirz, Mr. Albert    0  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)    1  22.0      1      1
#
#     Ticket     Fare Cabin  FamilySize  Embarked_Q  Embarked_S
# 0   330911   7.8292   NaN           1        True       False
# 1   363272   7.0000   NaN           2       False        True
# 2   240276   9.6875   NaN           1        True       False
# 3   315154   8.6625   NaN           1       False        True
# ...

# %%
x = df[['Pclass','Sex','Age']]
y = df['Survived']
sns.countplot(x='Sex', hue='Survived', data=df)
plt.show()

# %%
survival_counts = df['Survived'].value_counts()
plt.pie(survival_counts, labels=['Not Survived','Survived'],autopct='%1.1f%%')
plt.title("Survival Distribution")
plt.show()

# %%
df['AgeGroup']=pd.cut(df['Age'],bins=[0,12,18,35,60,100],
labels=['Child','Teen','Young','Adult','Senior'])

# %%
age_survival=df.groupby(['AgeGroup','Survived']).size().unstack()
print(age_survival)
# Out:
# Survived    0   1
# AgeGroup
# Child      13  12
# Teen       17  12
# Young     111  62
# Adult      57  37
# Senior      7   4

# %%
age_survival.plot(kind='bar')
plt.title("Survival Count by Age Group")
plt.xlabel('Age Group')
plt.ylabel('Count')
plt.show()

# %%
sns.histplot(df['Age'],kde=True)
plt.title("Age Distribution")
plt.show()

# %%
df.to_csv("tested.csv", index=False)
